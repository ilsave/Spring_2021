# %% [markdown]
# Беляева Любовь Андреевна 19-ИВТ-2
# 6-вариант

# %% [markdown]
# Лабораторная работа №2

# %% [markdown]
# Описание значений используемых полей (признаков) в исследуемом наборе данных.

# %% [markdown]
# Country - страна;
# Region - регион;
# Happiness Rank - Ранг Счастья;
# Happiness Score - Оценка Счастья;
# Standard Error - Стандартная ошибка;
# Economy (GDP per Capita) - Экономика (ВВП на душу населения);
# Family - семья;
# Health (Life Expectancy) - Здоровье (Ожидаемая продолжительность жизни);
# Freedom - Свобода;
# Trust_Government_Corruption - Доверие, коррупция в правительстве;
# Generosity - щедрость;
# Dystopia Residual - Антиутопия остаточная;

# %% [markdown]
# 1.Визуализируйте корреляции между признаками, находящимися в наборе данных (heatmap). Сделайте выводы.

# %%
import numpy as np

# %%
import pandas as pd
# %matplotlib inline

# %%
import seaborn as sns

# %%
pass_data1 = pd.read_csv('C:/Users/Админ/Downloads/лб1/!data/6_happiness/world-happiness-report/H2015.csv')
pass_data1
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
sns.heatmap(pass_data1.corr(),annot=True)#функция для отображения коэффициента корреляции
# Out:
# <AxesSubplot:>

# %%
pass_data2 = pd.read_csv('C:/Users/Админ/Downloads/лб1/!data/6_happiness/world-happiness-report/H2016.csv')
pass_data2
# Out:
#          Country                           Region  Happiness Rank  \
# 0        Denmark                   Western Europe               1
# 1    Switzerland                   Western Europe               2
# 2        Iceland                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4        Finland                   Western Europe               5
# ..           ...                              ...             ...
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness Score  Lower Confidence Interval  Upper Confidence Interval  \
# 0              7.526                      7.460                      7.592
# ...

# %%
sns.heatmap(pass_data2.corr(),annot=True)#функция для отображения коэффициента корреляции
# Out:
# <AxesSubplot:>

# %% [markdown]
# Корреляция – это мера зависимости одного показателя от другого.
# Коэффициент корреляции - это число, которое находится в промежутке от -1 до 1. Отражает силу и полюс взаимосвязи величин.
# - r=-1 означает максимальную обратную связь.
# - r=1 максимальную прямую связь.
# - r=0 означает, что никакой связи не выявлено.

# %%
pass_data3 = pd.read_csv('C:/Users/Админ/Downloads/лб1/!data/6_happiness/world-happiness-report/H2017.csv')
pass_data3
# Out:
#                       Country Region  Happiness Rank  Happiness Score  \
# 0                      Norway      1           7.537         7.594445
# 1                     Denmark      2           7.522         7.581728
# 2                     Iceland      3           7.504         7.622030
# 3                 Switzerland      4           7.494         7.561772
# 4                     Finland      5           7.469         7.527542
# ..                        ...    ...             ...              ...
# 150                    Rwanda    151           3.471         3.543030
# 151                     Syria    152           3.462         3.663669
# 152                  Tanzania    153           3.349         3.461430
# 153                   Burundi    154           2.905         3.074690
# 154  Central African Republic    155           2.693         2.864884
#
#      Lower Confidence Interval  Upper Confidence Interval  \
# 0                     7.479556                   1.616463
# ...

# %%
sns.heatmap(pass_data3.corr(),annot=True)#функция для отображения коэффициента корреляции
# Out:
# <AxesSubplot:>

# %% [markdown]
# 2.Постройте график счастья по регионам, страны на графике должны представляться отдельными точками.

# %%
import matplotlib.pyplot as plt

# %%
pass_data1.groupby('Region').sum().plot()
sns.set(rc={'figure.figsize':(20, 5)})
plt.plot(pass_data1['Country'].head(),'ro')

# %%
pass_data1['Country'].head()
# Out:
# 0    Switzerland
# 1        Iceland
# 2        Denmark
# 3         Norway
# 4         Canada
# Name: Country, dtype: object

# %%
pass_data2.groupby('Region').sum().plot()
sns.set(rc={'figure.figsize':(20, 5)})
plt.plot(pass_data1['Country'].head(),'ro')

# %%
pass_data2['Country'].head()
# Out:
# 0        Denmark
# 1    Switzerland
# 2        Iceland
# 3         Norway
# 4        Finland
# Name: Country, dtype: object

# %% [markdown]
# 3.Оцените количество счастья по годам по регионам.

# %%
print(pass_data1.groupby(['Region','Happiness Score'])['Region'].count())#3
# Out:
# Region                      Happiness Score
# Australia and New Zealand   7.284              1
#                             7.286              1
# Central and Eastern Europe  4.218              1
#                             4.297              1
#                             4.350              1
#                                               ..
# Western Europe              7.406              1
#                             7.522              1
#                             7.527              1
#                             7.561              1
#                             7.587              1
# Name: Region, Length: 158, dtype: int64

# %%
print(pass_data2.groupby(['Region','Country','Happiness Score'])['Region'].count())#3
# Out:
# Region                      Country         Happiness Score
# Australia and New Zealand   Australia       7.313              1
#                             New Zealand     7.334              1
# Central and Eastern Europe  Albania         4.655              1
#                             Armenia         4.360              1
#                             Azerbaijan      5.291              1
#                                                               ..
# Western Europe              Portugal        5.123              1
#                             Spain           6.361              1
#                             Sweden          7.291              1
#                             Switzerland     7.509              1
#                             United Kingdom  6.725              1
# Name: Region, Length: 157, dtype: int64

# %% [markdown]
# 4.Определите наиболее сильно изменяющиеся параметры по разным странам в разные годы.

# %%
pass_data1.std(axis = 0, skipna = True)#стандартное отклонение всех числовых столбцов в кадре данных. Мы собираемся пропустить значения NaN при расчете стандартного отклонения.
# Out:
# Happiness Rank                 45.754363
# Happiness Score                 1.145010
# Standard Error                  0.017146
# Economy (GDP per Capita)        0.403121
# Family                          0.272369
# Health (Life Expectancy)        0.247078
# Freedom                         0.150693
# Trust_Government_Corruption     0.120034
# Generosity                      0.126685
# Dystopia Residual               0.553550
# dtype: float64

# %%
pass_data2.std(axis = 0, skipna = True)
# Out:
# Happiness Rank                 45.466030
# Happiness Score                 1.141674
# Lower Confidence Interval       1.148043
# Upper Confidence Interval       1.136493
# Economy (GDP per Capita)        0.412595
# Family                          0.266706
# Health (Life Expectancy)        0.229349
# Freedom                         0.145507
# Trust_Government_Corruption     0.111038
# Generosity                      0.133756
# Dystopia Residual               0.542220
# dtype: float64

# %%
pass_data3.std(axis = 0, skipna = True)
# Out:
# Happiness Rank                 5.392846
# Happiness Score                1.118515
# Lower Confidence Interval      1.145220
# Upper Confidence Interval      0.548297
# Economy (GDP per Capita)       0.288679
# Family                         0.241846
# Health (Life Expectancy)       0.155886
# Freedom                        0.135817
# Trust_Government_Corruption    0.102739
# Generosity                     0.504830
# Dystopia Residual                   NaN
# dtype: float64

# %% [markdown]
# 5.Определите страны, появляющиеся и исчезающие в рейтинге стран.

# %%
pass_data1.sort_values("Country", inplace = True)# сортировка по стране
bool_series = pass_data1["Country"].duplicated()# создание серии bool
pass_data1.head()# отображение данных
pass_data1[bool_series]
# Out:
# Empty DataFrame
# Columns: [Country, Region, Happiness Rank, Happiness Score, Standard Error, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Trust_Government_Corruption, Generosity, Dystopia Residual]
# Index: []

# %%
pass_data1['Country'].head()
# Out:
# 0    Switzerland
# 1        Iceland
# 2        Denmark
# 3         Norway
# 4         Canada
# Name: Country, dtype: object

# %%
pass_data2.sort_values("Country", inplace = True)
bool_series = pass_data2["Country"].duplicated()
pass_data2.head()
pass_data2[bool_series]
# Out:
# Empty DataFrame
# Columns: [Country, Region, Happiness Rank, Happiness Score, Lower Confidence Interval, Upper Confidence Interval, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Trust_Government_Corruption, Generosity, Dystopia Residual]
# Index: []

# %%
pass_data2['Country'].head()
# Out:
# 153    Afghanistan
# 108        Albania
# 37         Algeria
# 140         Angola
# 25       Argentina
# Name: Country, dtype: object

# %%
pass_data3.sort_values("Country", inplace = True)
bool_series = pass_data3["Country"].duplicated()
pass_data3.head()
pass_data3[bool_series]
# Out:
# Empty DataFrame
# Columns: [Country, Region, Happiness Rank, Happiness Score, Lower Confidence Interval, Upper Confidence Interval, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Trust_Government_Corruption, Generosity, Dystopia Residual]
# Index: []

# %%
pass_data3['Country'].head()
# Out:
# 0         Norway
# 1        Denmark
# 2        Iceland
# 3    Switzerland
# 4        Finland
# Name: Country, dtype: object

# %% [markdown]
# 6.Удалите строки с пропущенными значениями. Выведите размер набора данных до и после удаления.

# %%
pass_data1.shape
# Out:
# (158, 12)

# %%
#6
pass_data1.isnull().head()#отсутствие данных
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 152    False   False           False            False           False
# 94     False   False           False            False           False
# 67     False   False           False            False           False
# 136    False   False           False            False           False
# 29     False   False           False            False           False
#
#      Economy (GDP per Capita)  Family  Health (Life Expectancy)  Freedom  \
# 152                     False   False                     False    False
# 94                      False   False                     False    False
# 67                      False   False                     False    False
# 136                     False   False                     False    False
# 29                      False   False                     False    False
#
#      Trust_Government_Corruption  Generosity  Dystopia Residual
# ...

# %%
pass_data1.dropna()#удаление пропущенных значений
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
pass_data1.shape
# Out:
# (158, 12)

# %%
pass_data2.shape
# Out:
# (157, 14)

# %%
#6
pass_data2.isnull().head()#отсутствие данных
# Out:
#      Country  Region  Happiness Rank  Happiness Score  \
# 153    False   False           False            False
# 108    False   False           False            False
# 37     False   False           False            False
# 140    False   False           False            False
# 25     False   False           False            False
#
#      Lower Confidence Interval  Upper Confidence Interval  \
# 153                      False                      False
# 108                      False                      False
# 37                       False                      False
# 140                      False                      False
# 25                       False                      False
#
#      Economy (GDP per Capita)  Family  Health (Life Expectancy)  Freedom  \
# 153                     False   False                     False    False
# 108                     False   False                     False    False
# ...

# %%
pass_data2.dropna()#удаление пропущенных значений
# Out:
#          Country                           Region  Happiness Rank  \
# 153  Afghanistan                    Southern Asia             154
# 108      Albania       Central and Eastern Europe             109
# 37       Algeria  Middle East and Northern Africa              38
# 140       Angola               Sub-Saharan Africa             141
# 25     Argentina      Latin America and Caribbean              26
# ..           ...                              ...             ...
# 43     Venezuela      Latin America and Caribbean              44
# 95       Vietnam                Southeastern Asia              96
# 146        Yemen  Middle East and Northern Africa             147
# 105       Zambia               Sub-Saharan Africa             106
# 130     Zimbabwe               Sub-Saharan Africa             131
#
#      Happiness Score  Lower Confidence Interval  Upper Confidence Interval  \
# 153            3.360                      3.288                      3.432
# ...

# %%
pass_data2.shape
# Out:
# (157, 14)

# %%
pass_data3.shape
# Out:
# (155, 13)

# %%
#6
pass_data3.isnull().head()#отсутствие данных
# Out:
#    Country  Region  Happiness Rank  Happiness Score  \
# 0    False   False           False            False
# 1    False   False           False            False
# 2    False   False           False            False
# 3    False   False           False            False
# 4    False   False           False            False
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      False                      False
# 1                      False                      False
# 2                      False                      False
# 3                      False                      False
# 4                      False                      False
#
#    Economy (GDP per Capita)  Family  Health (Life Expectancy)  Freedom  \
# 0                     False   False                     False    False
# 1                     False   False                     False    False
# 2                     False   False                     False    False
# ...

# %%
pass_data3.dropna()#удаление пропущенных значений
# Out:
#              Country  Region  Happiness Rank  Happiness Score  \
# 70  Hong Kong S.A.R.   China            71.0            5.472
#
#     Lower Confidence Interval  Upper Confidence Interval  \
# 70                   5.549594                   5.394406
#
#     Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 70                  1.551675  1.262791                  0.943062  0.490969
#
#     Trust_Government_Corruption  Generosity  Dystopia Residual
# 70                     0.374466    0.293934           0.554633

# %%
pass_data3.shape
# Out:
# (155, 13)

# %% [markdown]
# 7.Вычислите корреляцию Пирсона и Спирмена между признаками Trust.Government.Corruption и Family. Сравните полученные величины корреляции. Постройте гистограммы для указанных признаков. Оцените значение p-value.

# %%
from scipy import stats
#корреляция Пирсона
a = pass_data1['Trust_Government_Corruption']
b = pass_data1['Family']
stats.pearsonr(a, b)
# Out:
# (0.20560511187180397, 0.009551833256262169)

# %%
from scipy import stats
#корреляция Спирмена 
stats.spearmanr(pass_data1['Trust_Government_Corruption'], pass_data1['Family'])
# Out:
# SpearmanrResult(correlation=0.18459942329799503, pvalue=0.020235828494205098)

# %%
pass_data1.Trust_Government_Corruption.hist(bins=30)
# Out:
# <AxesSubplot:>

# %%
pass_data1.Family.hist(bins=30)
# Out:
# <AxesSubplot:>

# %%
#корреляция Пирсона
a = pass_data2['Trust_Government_Corruption']
b = pass_data2['Family']
stats.pearsonr(a, b)
# Out:
# (0.21356093757197214, 0.007240342953719788)

# %%
#корреляция Спирмена
stats.spearmanr(pass_data2['Trust_Government_Corruption'], pass_data2['Family'])
# Out:
# SpearmanrResult(correlation=0.177294402482085, pvalue=0.026325994511410922)

# %%
pass_data2.Trust_Government_Corruption.hist(bins=30)
# Out:
# <AxesSubplot:>

# %%
pass_data2.Family.hist(bins=30)
# Out:
# <AxesSubplot:>

# %%
#корреляция Пирсона
a = pass_data3['Trust_Government_Corruption']
b = pass_data3['Family']
stats.pearsonr(a, b)
# Out:
# (0.30055368108565295, 0.00014480649068089382)

# %%
#корреляция Спирмена
stats.spearmanr(pass_data3['Trust_Government_Corruption'], pass_data3['Family'])
# Out:
# SpearmanrResult(correlation=0.17597241468209207, pvalue=0.028507870712373984)

# %%
pass_data3.Trust_Government_Corruption.hist(bins=30)
# Out:
# <AxesSubplot:>

# %%
pass_data3.Family.hist(bins=30)
# Out:
# <AxesSubplot:>

# %% [markdown]
# 8.Добавьте в набор данных признак, являющийся суммой двух других признаков.

# %%
#8
pass_data1['Life expectancy'] = pass_data1['Happiness Rank']+pass_data1['Happiness Score']
pass_data1
# Out:
#          Country                           Region  Happiness Rank  \
# 152  Afghanistan                    Southern Asia             153
# 94       Albania       Central and Eastern Europe              95
# 67       Algeria  Middle East and Northern Africa              68
# 136       Angola               Sub-Saharan Africa             137
# 29     Argentina      Latin America and Caribbean              30
# ..           ...                              ...             ...
# 22     Venezuela      Latin America and Caribbean              23
# 74       Vietnam                Southeastern Asia              75
# 135        Yemen  Middle East and Northern Africa             136
# 84        Zambia               Sub-Saharan Africa              85
# 114     Zimbabwe               Sub-Saharan Africa             115
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 152            3.575         0.03084                   0.31982  0.30285
# ...

# %%
#8
pass_data2['Life expectancy'] = pass_data2['Happiness Rank']+pass_data2['Happiness Score']
pass_data2
# Out:
#          Country                           Region  Happiness Rank  \
# 153  Afghanistan                    Southern Asia             154
# 108      Albania       Central and Eastern Europe             109
# 37       Algeria  Middle East and Northern Africa              38
# 140       Angola               Sub-Saharan Africa             141
# 25     Argentina      Latin America and Caribbean              26
# ..           ...                              ...             ...
# 43     Venezuela      Latin America and Caribbean              44
# 95       Vietnam                Southeastern Asia              96
# 146        Yemen  Middle East and Northern Africa             147
# 105       Zambia               Sub-Saharan Africa             106
# 130     Zimbabwe               Sub-Saharan Africa             131
#
#      Happiness Score  Lower Confidence Interval  Upper Confidence Interval  \
# 153            3.360                      3.288                      3.432
# ...

# %%
#8
pass_data3['Life expectancy'] = pass_data3['Happiness Rank']+pass_data3['Happiness Score']
pass_data3
# Out:
#          Country Region  Happiness Rank  Happiness Score  \
# 140  Afghanistan    141           3.794         3.873661
# 108      Albania    109           4.644         4.752464
# 52       Algeria     53           5.872         5.978286
# 139       Angola    140           3.795         3.951642
# 23     Argentina     24           6.599         6.690085
# ..           ...    ...             ...              ...
# 81     Venezuela     82           5.250         5.370032
# 93       Vietnam     94           5.074         5.147281
# 145        Yemen    146           3.593         3.692750
# 115       Zambia    116           4.514         4.644106
# 137     Zimbabwe    138           3.875         3.978700
#
#      Lower Confidence Interval  Upper Confidence Interval  \
# 140                   3.714338                   0.401477
# 108                   4.535536                   0.996193
# 52                    5.765714                   1.091864
# ...

# %% [markdown]
# Результат выполнения следующих функций библиотеки Pandas: head, tail, info, describe, dropna, drop_duplicates, shape. Показать результат их применения к данным.

# %%
pass_data1.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust_Government_Corruption  Generosity  \
# 0                   0.94143  0.66557                      0.41978     0.29678
# 1                   0.94784  0.62877                      0.14145     0.43630
# ...

# %%
pass_data1.tail()#используется для возврата нижних n (5 по умолчанию) строк фрейма данных или серии.
# Out:
#      Country                           Region  Happiness Rank  \
# 153   Rwanda               Sub-Saharan Africa             154
# 154    Benin               Sub-Saharan Africa             155
# 155    Syria  Middle East and Northern Africa             156
# 156  Burundi               Sub-Saharan Africa             157
# 157     Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust_Government_Corruption  \
# 153                   0.42864  0.59201                      0.55191
# ...

# %%
pass_data1.info()#используется для получения краткой сводки данных.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Country                      158 non-null    object
#  1   Region                       158 non-null    object
#  2   Happiness Rank               158 non-null    int64
#  3   Happiness Score              158 non-null    float64
#  4   Standard Error               158 non-null    float64
#  5   Economy (GDP per Capita)     158 non-null    float64
#  6   Family                       158 non-null    float64
#  7   Health (Life Expectancy)     158 non-null    float64
#  8   Freedom                      158 non-null    float64
#  9   Trust_Government_Corruption  158 non-null    float64
#  10  Generosity                   158 non-null    float64
#  11  Dystopia Residual            158 non-null    float64
# dtypes: float64(9), int64(1), object(2)
# ...

# %%
pass_data1.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
pass_data1.dropna()
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
pass_data1.drop_duplicates(subset='Country')
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
pass_data1.shape
# Out:
# (158, 12)
