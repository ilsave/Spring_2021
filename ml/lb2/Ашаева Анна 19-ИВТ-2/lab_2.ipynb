# %%
import numpy as np

# %%
import pandas as pd
# %matplotlib inline

# %%
import seaborn as sns #библеотека визуализации данных в Python
import sklearn as sk

# %%
df=pd.read_csv('autos.csv', encoding='iso-8859-1')
df
# Out:
#                 dateCrawled                                          name  \
# 0       2016-03-24 11:52:17                                    Golf_3_1.6
# 1       2016-03-24 10:58:45                          A5_Sportback_2.7_Tdi
# 2       2016-03-14 12:52:21                Jeep_Grand_Cherokee_"Overland"
# 3       2016-03-17 16:54:04                            GOLF_4_1_4__3TÜRER
# 4       2016-03-31 17:25:20                Skoda_Fabia_1.4_TDI_PD_Classic
# ...                     ...                                           ...
# 371523  2016-03-14 17:48:27                    Suche_t4___vito_ab_6_sitze
# 371524  2016-03-05 19:56:21         Smart_smart_leistungssteigerung_100ps
# 371525  2016-03-19 18:57:12            Volkswagen_Multivan_T4_TDI_7DC_UY2
# 371526  2016-03-20 19:41:08                        VW_Golf_Kombi_1_9l_TDI
# 371527  2016-03-07 19:39:19  BMW_M135i_vollausgestattet_NP_52.720____Euro
#
#         seller offerType  price   abtest vehicleType  yearOfRegistration  \
# ...

# %%
df.head()
# Out:
#            dateCrawled                            name  seller offerType  \
# 0  2016-03-24 11:52:17                      Golf_3_1.6  privat   Angebot
# 1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  privat   Angebot
# 2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"  privat   Angebot
# 3  2016-03-17 16:54:04              GOLF_4_1_4__3TÜRER  privat   Angebot
# 4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic  privat   Angebot
#
#    price abtest vehicleType  yearOfRegistration    gearbox  powerPS  model  \
# 0    480   test         NaN                1993    manuell        0   golf
# 1  18300   test       coupe                2011    manuell      190    NaN
# 2   9800   test         suv                2004  automatik      163  grand
# 3   1500   test  kleinwagen                2001    manuell       75   golf
# 4   3600   test  kleinwagen                2008    manuell       69  fabia
#
#    kilometer  monthOfRegistration fuelType       brand notRepairedDamage  \
# ...

# %%
df.tail()
# Out:
#                 dateCrawled                                          name  \
# 371523  2016-03-14 17:48:27                    Suche_t4___vito_ab_6_sitze
# 371524  2016-03-05 19:56:21         Smart_smart_leistungssteigerung_100ps
# 371525  2016-03-19 18:57:12            Volkswagen_Multivan_T4_TDI_7DC_UY2
# 371526  2016-03-20 19:41:08                        VW_Golf_Kombi_1_9l_TDI
# 371527  2016-03-07 19:39:19  BMW_M135i_vollausgestattet_NP_52.720____Euro
#
#         seller offerType  price   abtest vehicleType  yearOfRegistration  \
# 371523  privat   Angebot   2200     test         NaN                2005
# 371524  privat   Angebot   1199     test      cabrio                2000
# 371525  privat   Angebot   9200     test         bus                1996
# 371526  privat   Angebot   3400     test       kombi                2002
# 371527  privat   Angebot  28990  control   limousine                2013
#
#           gearbox  powerPS        model  kilometer  monthOfRegistration  \
# ...

# %%
df.describe()
# Out:
#               price  yearOfRegistration        powerPS      kilometer  \
# count  3.715280e+05       371528.000000  371528.000000  371528.000000
# mean   1.729514e+04         2004.577997     115.549477  125618.688228
# std    3.587954e+06           92.866598     192.139578   40112.337051
# min    0.000000e+00         1000.000000       0.000000    5000.000000
# 25%    1.150000e+03         1999.000000      70.000000  125000.000000
# 50%    2.950000e+03         2003.000000     105.000000  150000.000000
# 75%    7.200000e+03         2008.000000     150.000000  150000.000000
# max    2.147484e+09         9999.000000   20000.000000  150000.000000
#
#        monthOfRegistration  nrOfPictures    postalCode
# count        371528.000000      371528.0  371528.00000
# mean              5.734445           0.0   50820.66764
# std               3.712412           0.0   25799.08247
# min               0.000000           0.0    1067.00000
# 25%               3.000000           0.0   30459.00000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 371528 entries, 0 to 371527
# Data columns (total 20 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   dateCrawled          371528 non-null  object
#  1   name                 371528 non-null  object
#  2   seller               371528 non-null  object
#  3   offerType            371528 non-null  object
#  4   price                371528 non-null  int64
#  5   abtest               371528 non-null  object
#  6   vehicleType          333659 non-null  object
#  7   yearOfRegistration   371528 non-null  int64
#  8   gearbox              351319 non-null  object
#  9   powerPS              371528 non-null  int64
#  10  model                351044 non-null  object
#  11  kilometer            371528 non-null  int64
#  12  monthOfRegistration  371528 non-null  int64
#  13  fuelType             338142 non-null  object
#  14  brand                371528 non-null  object
# ...

# %%
df.shape
# Out:
# (371528, 20)

# %%
df=df.drop(["dateCrawled", "seller", "offerType", "abtest", "monthOfRegistration", 
                                     "nrOfPictures", "postalCode"], axis = "columns")

# %%
df.head()
# Out:
#                              name  price vehicleType  yearOfRegistration  \
# 0                      Golf_3_1.6    480         NaN                1993
# 1            A5_Sportback_2.7_Tdi  18300       coupe                2011
# 2  Jeep_Grand_Cherokee_"Overland"   9800         suv                2004
# 3              GOLF_4_1_4__3TÜRER   1500  kleinwagen                2001
# 4  Skoda_Fabia_1.4_TDI_PD_Classic   3600  kleinwagen                2008
#
#      gearbox  powerPS  model  kilometer fuelType       brand  \
# 0    manuell        0   golf     150000   benzin  volkswagen
# 1    manuell      190    NaN     125000   diesel        audi
# 2  automatik      163  grand     125000   diesel        jeep
# 3    manuell       75   golf     150000   benzin  volkswagen
# 4    manuell       69  fabia      90000   diesel       skoda
#
#   notRepairedDamage          dateCreated             lastSeen
# 0               NaN  2016-03-24 00:00:00  2016-04-07 03:16:57
# ...

# %%
df.shape
# Out:
# (371528, 13)

# %%
df = df.dropna()
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (260921, 13)

# %%
df.boxplot(column=["yearOfRegistration"])
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column=["price"])
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column=["powerPS"])
# Out:
# <AxesSubplot:>

# %%
df = df[(df.yearOfRegistration > 2010) & (df.yearOfRegistration<2015)]
df = df[(df.price > 20000) & (df.price < 30000)]
df = df[(df.powerPS > 110) & (df.powerPS < 145)]
df
# Out:
#                                                      name  price vehicleType  \
# 98       BMW_318d_Aut.__Xenon__Navi__Sportsitze_FESTREIS!  23490   limousine
# 272     Volkswagen_Caravelle_Lang_DSG_Navi_Standheiz._...  26999         bus
# 754           VW_T5_Multivan_Special__AHK__Fahrradtraeger  28300         bus
# 1740                  Audi_A3_1.4_TFSI_Limousine_S_tronic  22900   limousine
# 2119                Audi_A4_Avant_2.0_TDI_DPF_multitronic  29999       kombi
# ...                                                   ...    ...         ...
# 369727        Volkswagen_Sharan_2.0_TDI_Blue_Motion_Style  24300         bus
# 369898                              Mercedes_Benz_CLA_180  23000       coupe
# 369957                              Mercedes_Benz_GLK_200  21500         suv
# 370150                             BMW_X1_xDrive18d_xLine  22999   limousine
# 371483  Mercedes_Benz_E_200_CDI_DPF_BlueEFFICIENCY_7G_...  20500   limousine
#
# ...

# %%
df.boxplot(column=["yearOfRegistration"])
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column=["price"])
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column=["powerPS"])
# Out:
# <AxesSubplot:>

# %%
df.shape
# Out:
# (1023, 13)

# %%
df.isnull().sum()#пропущенных данных нет (.fillna())
# Out:
# name                  0
# price                 0
# vehicleType           0
# yearOfRegistration    0
# gearbox               0
# powerPS               0
# model                 0
# kilometer             0
# fuelType              0
# brand                 0
# notRepairedDamage     0
# dateCreated           0
# lastSeen              0
# dtype: int64

# %%
sns.countplot(data=df, y='brand')
# Out:
# <AxesSubplot:xlabel='count', ylabel='brand'>

# %%
sns.countplot(data=df, y='vehicleType')
# Out:
# <AxesSubplot:xlabel='count', ylabel='vehicleType'>

# %%
sns.countplot(data=df, y='fuelType')
# Out:
# <AxesSubplot:xlabel='count', ylabel='fuelType'>

# %%
def get_name_lenght(name):
    return len(str(name))

df["nameLenght"] = df["name"].apply(get_name_lenght)
df.head()
# Out:
#                                                    name  price vehicleType  \
# 98     BMW_318d_Aut.__Xenon__Navi__Sportsitze_FESTREIS!  23490   limousine
# 272   Volkswagen_Caravelle_Lang_DSG_Navi_Standheiz._...  26999         bus
# 754         VW_T5_Multivan_Special__AHK__Fahrradtraeger  28300         bus
# 1740                Audi_A3_1.4_TFSI_Limousine_S_tronic  22900   limousine
# 2119              Audi_A4_Avant_2.0_TDI_DPF_multitronic  29999       kombi
#
#       yearOfRegistration    gearbox  powerPS        model  kilometer fuelType  \
# 98                  2013  automatik      143          3er      40000   diesel
# 272                 2013  automatik      140  transporter      80000   diesel
# 754                 2012    manuell      114  transporter      40000   diesel
# 1740                2014  automatik      125           a3      20000   benzin
# 2119                2013  automatik      143           a4      90000   diesel
#
# ...

# %%
correlation_heatmap = df.corr()
sns.heatmap(correlation_heatmap, cmap = 'YlGnBu', annot=False, fmt='.1f')#функция для отображения коэффициента корреляции
# Out:
# <AxesSubplot:>

# %%
df["nameAndFuelType"] = df["name"] + " " + df["fuelType"]
df
# Out:
#                                                      name  price vehicleType  \
# 98       BMW_318d_Aut.__Xenon__Navi__Sportsitze_FESTREIS!  23490   limousine
# 272     Volkswagen_Caravelle_Lang_DSG_Navi_Standheiz._...  26999         bus
# 754           VW_T5_Multivan_Special__AHK__Fahrradtraeger  28300         bus
# 1740                  Audi_A3_1.4_TFSI_Limousine_S_tronic  22900   limousine
# 2119                Audi_A4_Avant_2.0_TDI_DPF_multitronic  29999       kombi
# ...                                                   ...    ...         ...
# 369727        Volkswagen_Sharan_2.0_TDI_Blue_Motion_Style  24300         bus
# 369898                              Mercedes_Benz_CLA_180  23000       coupe
# 369957                              Mercedes_Benz_GLK_200  21500         suv
# 370150                             BMW_X1_xDrive18d_xLine  22999   limousine
# 371483  Mercedes_Benz_E_200_CDI_DPF_BlueEFFICIENCY_7G_...  20500   limousine
#
# ...
