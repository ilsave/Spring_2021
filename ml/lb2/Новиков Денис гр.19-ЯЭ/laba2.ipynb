# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as sps

# %matplotlib inline

# %%
nr=pd.read_csv('district wise rainfall normal.csv')
rain=pd.read_csv('rainfall in india 1901-2015.csv')
rain
# Out:
#                     SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0     ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1     ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2     ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3     ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4     ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
# ...                         ...   ...   ...    ...   ...    ...    ...    ...
# 4111                LAKSHADWEEP  2011   5.1    2.8   3.1   85.9  107.2  153.6
# 4112                LAKSHADWEEP  2012  19.2    0.1   1.6   76.8   21.2  327.0
# 4113                LAKSHADWEEP  2013  26.2   34.4  37.5    5.3   88.3  426.2
# 4114                LAKSHADWEEP  2014  53.2   16.1   4.4   14.9   57.4  244.1
# 4115                LAKSHADWEEP  2015   2.2    0.5   3.7   87.1  133.1  296.6
#
# ...

# %% [markdown]
# ### 1.Постройте графики количества осадков по годам в разных штатах. Сделайте выводы по построенным графикам

# %%
nrain=rain[["SUBDIVISION","YEAR","ANNUAL"]]
nrain.groupby(by='SUBDIVISION').plot(x='YEAR',y='ANNUAL', kind='bar', stacked='true',figsize=(20,10))
# Out:
# C:\Users\User\Desktop\Новая папка (2)\WPy64-3870\python-3.8.7.amd64\lib\site-packages\pandas\plotting\_matplotlib\core.py:328: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# SUBDIVISION
# ANDAMAN & NICOBAR ISLANDS             AxesSubplot(0.125,0.125;0.775x0.755)
# ARUNACHAL PRADESH                     AxesSubplot(0.125,0.125;0.775x0.755)
# ASSAM & MEGHALAYA                     AxesSubplot(0.125,0.125;0.775x0.755)
# BIHAR                                 AxesSubplot(0.125,0.125;0.775x0.755)
# CHHATTISGARH                          AxesSubplot(0.125,0.125;0.775x0.755)
# COASTAL ANDHRA PRADESH                AxesSubplot(0.125,0.125;0.775x0.755)
# COASTAL KARNATAKA                     AxesSubplot(0.125,0.125;0.775x0.755)
# ...

# %% [markdown]
# ### 3. Постройте графики количества осадков по штатам, используйте boxplot. Сделайте выводы по построенным графикам.

# %%
fig=plt.figure(figsize=(20,10))
plt.xticks(rotation='vertical')
sns.boxplot(data=rain,x='SUBDIVISION', y='ANNUAL')
# Out:
# <AxesSubplot:xlabel='SUBDIVISION', ylabel='ANNUAL'>

# %% [markdown]
# ### 5. Выведите уникальные имена штатов и территорий Индии

# %%
print(rain.SUBDIVISION.unique())
print('Количество ',len(rain.SUBDIVISION.unique()))
# Out:
# ['ANDAMAN & NICOBAR ISLANDS' 'ARUNACHAL PRADESH' 'ASSAM & MEGHALAYA'
#  'NAGA MANI MIZO TRIPURA' 'SUB HIMALAYAN WEST BENGAL & SIKKIM'
#  'GANGETIC WEST BENGAL' 'ORISSA' 'JHARKHAND' 'BIHAR' 'EAST UTTAR PRADESH'
#  'WEST UTTAR PRADESH' 'UTTARAKHAND' 'HARYANA DELHI & CHANDIGARH' 'PUNJAB'
#  'HIMACHAL PRADESH' 'JAMMU & KASHMIR' 'WEST RAJASTHAN' 'EAST RAJASTHAN'
#  'WEST MADHYA PRADESH' 'EAST MADHYA PRADESH' 'GUJARAT REGION'
#  'SAURASHTRA & KUTCH' 'KONKAN & GOA' 'MADHYA MAHARASHTRA' 'MATATHWADA'
#  'VIDARBHA' 'CHHATTISGARH' 'COASTAL ANDHRA PRADESH' 'TELANGANA'
#  'RAYALSEEMA' 'TAMIL NADU' 'COASTAL KARNATAKA' 'NORTH INTERIOR KARNATAKA'
#  'SOUTH INTERIOR KARNATAKA' 'KERALA' 'LAKSHADWEEP']
# Количество  36

# %% [markdown]
# ### 6. Определите количество лет наблюдений для каждого штата

# %%
rain['SUBDIVISION'].value_counts()
# Out:
# CHHATTISGARH                          115
# JHARKHAND                             115
# MADHYA MAHARASHTRA                    115
# EAST UTTAR PRADESH                    115
# COASTAL ANDHRA PRADESH                115
# PUNJAB                                115
# RAYALSEEMA                            115
# WEST UTTAR PRADESH                    115
# BIHAR                                 115
# SAURASHTRA & KUTCH                    115
# SUB HIMALAYAN WEST BENGAL & SIKKIM    115
# TELANGANA                             115
# ASSAM & MEGHALAYA                     115
# WEST RAJASTHAN                        115
# ORISSA                                115
# HARYANA DELHI & CHANDIGARH            115
# COASTAL KARNATAKA                     115
# GUJARAT REGION                        115
# EAST RAJASTHAN                        115
# GANGETIC WEST BENGAL                  115
# NAGA MANI MIZO TRIPURA                115
# UTTARAKHAND                           115
# ...

# %% [markdown]
# ### 7. Определите штат с наименьшим количеством наблюдений

# %%
rain['SUBDIVISION'].value_counts().index[-1]
# Out:
# 'ARUNACHAL PRADESH'

# %% [markdown]
# ### 9. Вычислите корреляцию Пирсона и Спирмена между признаками NOV и MAR. Сравните полученные величины корреляции. Постройте гистограммы для указанных признаков. Оцените значение p-value.

# %%
stats.spearmanr(nr['MAR'], nr['NOV']) #корреляция Спирмана
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-e4548d0874ae> in <module>
# ----> 1 stats.spearmanr(nr['MAR'], nr['NOV']) #корреляция Спирмана
#
# NameError: name 'stats' is not defined

# %%
stats.pearsonr(nr['MAR'], nr['NOV']) #корреляция Пирсона

# %%
rain.NOV.hist(bins = 50)

# %%
rain.MAR.hist(bins = 50)

# %% [markdown]
# ### 2. Постройте графики количества осадков по месяцам по всем годам кумулятивно.Сделайте выводы по построенным графикам.

# %%
rain.groupby(by='YEAR').sum()[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].plot(kind='bar',stacked='true',figsize=(20,10))

# %% [markdown]
# ### 8. Добавьте в набор данных признак, являющийся суммой двух других признаков.

# %%
rain["JAN+FEB"]=rain["JAN"]+rain["FEB"]
rain.head()

# %% [markdown]
# ### 4. Определите штаты, для которых количество осадков минимально и максимально.

# %%
aa=rain.groupby(by='SUBDIVISION').sum()[['ANNUAL']].sort_values(by='ANNUAL', ascending=False)
aa

# %%
print('Наименьшее ', aa.index.values[-1])
print('Наибольшее ', aa.index.values[0])
