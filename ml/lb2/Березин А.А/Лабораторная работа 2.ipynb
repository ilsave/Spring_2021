# %% [markdown]
# # Титаник. Вариант 1 Березин А.А. гр.М19-ЯЭ

# %%
import pandas as pd

# %%
t1=pd.read_csv('train.csv')
t1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
t1.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %% [markdown]
# # 1.Колличество мужчин и женщин, которые ехали на карабле

# %%
b=len(t1)
print(b)
# Out:
# 891

# %% [markdown]
# # 2.Определить какой части пасажиров удалость выжить. Посчитать долю выживших пасажиров

# %%
a=t1[(t1.Survived == 1)].shape
print(a[0])
survide1=a[0]/b
print(survide1)
# Out:
# 342
# 0.3838383838383838

# %% [markdown]
# ### 3. Какую долю пасажиры первого класса составляли среди всех пасажиров

# %%
c=t1[(t1.Pclass==1)].shape
print(c[0])
pclass1=c[0]/b
print(pclass1)
# Out:
# 216
# 0.24242424242424243

# %% [markdown]
# ### 4. Какого возраста были пасажиры? Посчитайте среднее и медиану возраса пасажиров.

# %%
t1[['Age']].head()
# Out:
#     Age
# 0  22.0
# 1  38.0
# 2  26.0
# 3  35.0
# 4  35.0

# %%
t1['Age'].mean()
# Out:
# 29.69911764705882

# %%
t1['Age'].median()
# Out:
# 28.0

# %% [markdown]
# ### 5. Коррелируют ли число братьев/сестёр с числом родителей/детей?

# %%
t1[['SibSp','Parch']].corr(method='pearson')
# Out:
#           SibSp     Parch
# SibSp  1.000000  0.414838
# Parch  0.414838  1.000000

# %%
import numpy as np

# %%
import seaborn as sns

# %%
sns.scatterplot(data=t1, x='SibSp', y='Parch');

# %% [markdown]
# ### 6. Самое популярное женское имя на карабле.

# %%
r=t1[t1['Sex']=='female']
r.head(10)
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 14           15         0       3
# 15           16         1       2
# 18           19         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# ...

# %%
r1=r[['Name']]
r1.head(10)
# Out:
#                                                  Name
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                              Heikkinen, Miss. Laina
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                 Nasser, Mrs. Nicholas (Adele Achem)
# 10                    Sandstrom, Miss. Marguerite Rut
# 11                           Bonnell, Miss. Elizabeth
# 14               Vestrom, Miss. Hulda Amanda Adolfina
# 15                   Hewlett, Mrs. (Mary D Kingcome)
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vande...

# %%
r1.values
# Out:
# array([['Cumings, Mrs. John Bradley (Florence Briggs Thayer)'],
#        ['Heikkinen, Miss. Laina'],
#        ['Futrelle, Mrs. Jacques Heath (Lily May Peel)'],
#        ['Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)'],
#        ['Nasser, Mrs. Nicholas (Adele Achem)'],
#        ['Sandstrom, Miss. Marguerite Rut'],
#        ['Bonnell, Miss. Elizabeth'],
#        ['Vestrom, Miss. Hulda Amanda Adolfina'],
#        ['Hewlett, Mrs. (Mary D Kingcome) '],
#        ['Vander Planke, Mrs. Julius (Emelia Maria Vandemoortele)'],
#        ['Masselmani, Mrs. Fatima'],
#        ['McGowan, Miss. Anna "Annie"'],
#        ['Palsson, Miss. Torborg Danira'],
#        ['Asplund, Mrs. Carl Oscar (Selma Augusta Emilia Johansson)'],
#        ['O\'Dwyer, Miss. Ellen "Nellie"'],
#        ['Spencer, Mrs. William Augustus (Marie Eugenie)'],
#        ['Glynn, Miss. Mary Agatha'],
#        ['Vander Planke, Miss. Augusta Maria'],
#        ['Nicola-Yarred, Miss. Jamila'],
# ...

# %%
new=r['Name'].str.split('. ', n=3, expand = True)
new[2]
# Out:
# 1           Joh
# 2         Laina
# 3        Jacque
# 8          Osca
# 9       Nichola
#          ...
# 880      Willia
# 882        Gerd
# 885      Willia
# 887     Margare
# 888    Catherin
# Name: 2, Length: 314, dtype: object

# %%
new[2].value_counts()
# Out:
# Willia     13
# Thoma       6
# Mary        6
# Ann         6
# Joh         6
#            ..
# Susan       1
# Hjalma      1
# Sa          1
# Elina       1
# Bridget     1
# Name: 2, Length: 218, dtype: int64

# %% [markdown]
# ### 7. Коррелирует ли класс, в коором едут пасажиры, с выживаемостью

# %%
t1[['Pclass','Survived']].corr(method='pearson')
# Out:
#             Pclass  Survived
# Pclass    1.000000 -0.338481
# Survived -0.338481  1.000000

# %%
t1[['Pclass','Survived']].corr(method='spearman')
# Out:
#             Pclass  Survived
# Pclass    1.000000 -0.339668
# Survived -0.339668  1.000000

# %%
sns.scatterplot(data=t1, x='Pclass', y='Survived');

# %%
t7=t1[t1['Survived']==1]
t7.head(10)
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 15           16         1       2
# 17           18         1       2
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# ...

# %%
sns.scatterplot(data=t7, x='Pclass', y='Survived');

# %%
n7=t7['Pclass'].value_counts()
n7
# Out:
# 1    136
# 3    119
# 2     87
# Name: Pclass, dtype: int64

# %%
t7.Pclass.hist(bins=30)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 8. Визуализируйте гистограммы возраста для выжавших и не выжавших пасажиров

# %%
t8=t1.groupby('Survived')
t8.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
t8.Age.hist()
# Out:
# Survived
# 0    AxesSubplot(0.125,0.125;0.775x0.755)
# 1    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: Age, dtype: object

# %%
t8=t1[lambda x: x['Survived']==0]
t8.Age.hist()
t9=t1[lambda x: x['Survived']==1]
t9.Age.hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 9. Визуализируйте гистограммы возраста для выживших и не выживших пасажиров по классам

# %%
t1.groupby(['Survived', 'Pclass']).Age.plot.hist(legend=bool)
# Out:
# Survived  Pclass
# 0         1         AxesSubplot(0.125,0.125;0.775x0.755)
#           2         AxesSubplot(0.125,0.125;0.775x0.755)
#           3         AxesSubplot(0.125,0.125;0.775x0.755)
# 1         1         AxesSubplot(0.125,0.125;0.775x0.755)
#           2         AxesSubplot(0.125,0.125;0.775x0.755)
#           3         AxesSubplot(0.125,0.125;0.775x0.755)
# Name: Age, dtype: object

# %% [markdown]
# ### 10. Столбчатая диаграмма количества людей: мужчин, женщин, детей

# %%
t1[['Sex']].value_counts()
# Out:
# Sex
# male      577
# female    314
# dtype: int64

# %%
t1[t1['Age']<=18].count()
# Out:
# PassengerId    139
# Survived       139
# Pclass         139
# Name           139
# Sex            139
# Age            139
# SibSp          139
# Parch          139
# Ticket         139
# Fare           139
# Cabin           23
# Embarked       139
# dtype: int64

# %%
t1['Sex']=np.where((t1.Age<=18), 'Kids', t1.Sex)
t1.groupby(['Sex']).count().plot(y='PassengerId',kind='bar', rot=45)
# Out:
# <AxesSubplot:xlabel='Sex'>

# %%
t1[lambda x: x['Age']<=18].count().plot(x='Sex',kind='bar', rot=45)
# Out:
# <AxesSubplot:>

# %%
Kids=t1['Sex']
t1['Kids']=Kids
t1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
t1['Sex']=np.where((t1.Age<=18), 'Kids', t1.Sex)
t1.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...
