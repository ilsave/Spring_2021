# %% [markdown]
# ### Жеглов Глеб 19-ИВТ-2
# ### Вариант 2
# #### 1. Подсчитайте количество отменённых рейсов.
# #### 2. Определите аэропорт, рейсы для которого отменяются наиболее часто.
# #### 3. Определите коэффициент корреляции Пирсона и Спирмена между отменой рейса и днём недели, месяцем, авиакомпанией, аэропортом. Оцените значение p-value. Постройте плотность распределения признаков.
# #### 4. Подсчитайте для трёх выбранных авиакомпаний: количество рейсов, количество отменённых рейсов, количество перенаправленных рейсов.
# #### 5. Определите скорость полёта для каждого рейса, скорость полёта среднюю для трёх выбранных авиакомпаний.
# #### 6. Визуализируйте тепловую карту частоты отмены рейсов. По одной оси – дни, по другой оси – рейс (для двух аэропортов).
# #### 7. Посчитайте и визуализируйте время задержки отправки и прибытия по трём аэропортам.
# #### 8. Определите для трёх выбранных аэропортов и визуализируйте задержки по каждой причине.
# #### 9. Определите авиакомпанию с максимальными задержками рейсов по отправке и прибытию.

# %%
import pandas as pd
flights_df = pd.read_csv('flights.csv')
# Out:
# D:\WinPython\WPy64-3870\python-3.8.7.amd64\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (7,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
print(flights_df)
# Out:
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0        2015      1    1            4      AS             98      N407AS
# 1        2015      1    1            4      AA           2336      N3KUAA
# 2        2015      1    1            4      US            840      N171US
# 3        2015      1    1            4      AA            258      N3HYAA
# 4        2015      1    1            4      AS            135      N527AS
# ...       ...    ...  ...          ...     ...            ...         ...
# 5819074  2015     12   31            4      B6            688      N657JB
# 5819075  2015     12   31            4      B6            745      N828JB
# 5819076  2015     12   31            4      B6           1503      N913JB
# 5819077  2015     12   31            4      B6            333      N527JB
# 5819078  2015     12   31            4      B6            839      N534JB
#
#         ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  \
# ...

# %%
flights_df.head()
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
# 1  2015      1    1            4      AA           2336      N3KUAA
# 2  2015      1    1            4      US            840      N171US
# 3  2015      1    1            4      AA            258      N3HYAA
# 4  2015      1    1            4      AS            135      N527AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  ARRIVAL_TIME  \
# 0            ANC                 SEA                    5  ...         408.0
# 1            LAX                 PBI                   10  ...         741.0
# 2            SFO                 CLT                   20  ...         811.0
# 3            LAX                 MIA                   20  ...         756.0
# 4            SEA                 ANC                   25  ...         259.0
#
#    ARRIVAL_DELAY  DIVERTED  CANCELLED  CANCELLATION_REASON  AIR_SYSTEM_DELAY  \
# ...

# %%
flights_df.tail()
# Out:
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 5819074  2015     12   31            4      B6            688      N657JB
# 5819075  2015     12   31            4      B6            745      N828JB
# 5819076  2015     12   31            4      B6           1503      N913JB
# 5819077  2015     12   31            4      B6            333      N527JB
# 5819078  2015     12   31            4      B6            839      N534JB
#
#         ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  \
# 5819074            LAX                 BOS                 2359  ...
# 5819075            JFK                 PSE                 2359  ...
# 5819076            JFK                 SJU                 2359  ...
# 5819077            MCO                 SJU                 2359  ...
# 5819078            JFK                 BQN                 2359  ...
#
#          ARRIVAL_TIME  ARRIVAL_DELAY  DIVERTED  CANCELLED  \
# ...

# %%
flights_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5819079 entries, 0 to 5819078
# Data columns (total 31 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   YEAR                 int64
#  1   MONTH                int64
#  2   DAY                  int64
#  3   DAY_OF_WEEK          int64
#  4   AIRLINE              object
#  5   FLIGHT_NUMBER        int64
#  6   TAIL_NUMBER          object
#  7   ORIGIN_AIRPORT       object
#  8   DESTINATION_AIRPORT  object
#  9   SCHEDULED_DEPARTURE  int64
#  10  DEPARTURE_TIME       float64
#  11  DEPARTURE_DELAY      float64
#  12  TAXI_OUT             float64
#  13  WHEELS_OFF           float64
#  14  SCHEDULED_TIME       float64
#  15  ELAPSED_TIME         float64
#  16  AIR_TIME             float64
#  17  DISTANCE             int64
#  18  WHEELS_ON            float64
#  19  TAXI_IN              float64
#  20  SCHEDULED_ARRIVAL    int64
#  21  ARRIVAL_TIME         float64
#  22  ARRIVAL_DELAY        float64
# ...

# %%
flights_df_2 = flights_df.describe()
flights_df_2
# Out:
#             YEAR         MONTH           DAY   DAY_OF_WEEK  FLIGHT_NUMBER  \
# count  5819079.0  5.819079e+06  5.819079e+06  5.819079e+06   5.819079e+06
# mean      2015.0  6.524085e+00  1.570459e+01  3.926941e+00   2.173093e+03
# std          0.0  3.405137e+00  8.783425e+00  1.988845e+00   1.757064e+03
# min       2015.0  1.000000e+00  1.000000e+00  1.000000e+00   1.000000e+00
# 25%       2015.0  4.000000e+00  8.000000e+00  2.000000e+00   7.300000e+02
# 50%       2015.0  7.000000e+00  1.600000e+01  4.000000e+00   1.690000e+03
# 75%       2015.0  9.000000e+00  2.300000e+01  6.000000e+00   3.230000e+03
# max       2015.0  1.200000e+01  3.100000e+01  7.000000e+00   9.855000e+03
#
#        SCHEDULED_DEPARTURE  DEPARTURE_TIME  DEPARTURE_DELAY      TAXI_OUT  \
# count         5.819079e+06    5.732926e+06     5.732926e+06  5.730032e+06
# mean          1.329602e+03    1.335204e+03     9.370158e+00  1.607166e+01
# std           4.837518e+02    4.964233e+02     3.708094e+01  8.895574e+00
# ...

# %%
flights_df_3 = flights_df.dropna(axis = 1)
flights_df_3
# Out:
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER ORIGIN_AIRPORT  \
# 0        2015      1    1            4      AS             98            ANC
# 1        2015      1    1            4      AA           2336            LAX
# 2        2015      1    1            4      US            840            SFO
# 3        2015      1    1            4      AA            258            LAX
# 4        2015      1    1            4      AS            135            SEA
# ...       ...    ...  ...          ...     ...            ...            ...
# 5819074  2015     12   31            4      B6            688            LAX
# 5819075  2015     12   31            4      B6            745            JFK
# 5819076  2015     12   31            4      B6           1503            JFK
# 5819077  2015     12   31            4      B6            333            MCO
# 5819078  2015     12   31            4      B6            839            JFK
#
# ...

# %%
flights_df.drop(["MONTH", "FLIGHT_NUMBER", "DIVERTED"], axis = 1)
# Out:
#          YEAR  DAY  DAY_OF_WEEK AIRLINE TAIL_NUMBER ORIGIN_AIRPORT  \
# 0        2015    1            4      AS      N407AS            ANC
# 1        2015    1            4      AA      N3KUAA            LAX
# 2        2015    1            4      US      N171US            SFO
# 3        2015    1            4      AA      N3HYAA            LAX
# 4        2015    1            4      AS      N527AS            SEA
# ...       ...  ...          ...     ...         ...            ...
# 5819074  2015   31            4      B6      N657JB            LAX
# 5819075  2015   31            4      B6      N828JB            JFK
# 5819076  2015   31            4      B6      N913JB            JFK
# 5819077  2015   31            4      B6      N527JB            MCO
# 5819078  2015   31            4      B6      N534JB            JFK
#
#         DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  DEPARTURE_TIME  \
# 0                       SEA                    5          2354.0
# ...

# %%
flights_df.drop_duplicates(subset = ['YEAR', 'MONTH', 'DAY', 'DAY_OF_WEEK'])
# Out:
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0        2015      1    1            4      AS             98      N407AS
# 13950    2015      1    2            5      AA           2400      N5CDAA
# 30691    2015      1    3            6      AA           2400      N5DKAA
# 46125    2015      1    4            7      AA           2400      N630AA
# 62477    2015      1    5            1      UA            203      N415UA
# ...       ...    ...  ...          ...     ...            ...         ...
# 5740666  2015     12   27            7      UA            460      N16703
# 5757175  2015     12   28            1      EV           4682      N15910
# 5773487  2015     12   29            2      AA           1230      N3JNAA
# 5789686  2015     12   30            3      AA           1230      N3CVAA
# 5805946  2015     12   31            4      AA           1230      N3HSAA
#
#         ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  \
# ...

# %%
flights_df.shape
# Out:
# (5819079, 31)

# %%
CANCELLED = flights_df[flights_df.CANCELLED == 1]['CANCELLED'].count()
CANCELLED
# Out:
# 89884

# %%
flights_max = flights_df[flights_df.CANCELLED == 1].groupby(['ORIGIN_AIRPORT', 'CANCELLED'])['CANCELLED'].count()
flights_max
# Out:
# ORIGIN_AIRPORT  CANCELLED
# 10136           1              7
# 10140           1              6
# 10141           1              1
# 10155           1              5
# 10157           1              3
#                             ...
# VPS             1             99
# WRG             1             11
# XNA             1            296
# YAK             1              5
# YUM             1             23
# Name: CANCELLED, Length: 609, dtype: int64

# %%
flights_max.sort_values()
# Out:
# ORIGIN_AIRPORT  CANCELLED
# CNY             1               1
# 12523           1               1
# 13290           1               1
# 14783           1               1
# 13433           1               1
#                              ...
# BOS             1            2654
# EWR             1            3110
# LGA             1            4531
# DFW             1            6254
# ORD             1            8548
# Name: CANCELLED, Length: 609, dtype: int64

# %%
Flight_AS = flights_df[flights_df.AIRLINE == 'AS']['AIRLINE'].count()
Flight_AS
# Out:
# 172521

# %%
CANCELLED_AS = flights_df[flights_df.CANCELLED == 1][flights_df.AIRLINE == 'AS']['CANCELLED'].count()
CANCELLED_AS
# Out:
# <ipython-input-115-1411c7b8add3>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   CANCELLED_AS = flights_df[flights_df.CANCELLED == 1][flights_df.AIRLINE == 'AS']['CANCELLED'].count()
# 669

# %%
DIVERTED_AS = flights_df[flights_df.DIVERTED == 1][flights_df.AIRLINE == 'AS']['DIVERTED'].count()
DIVERTED_AS
# Out:
# <ipython-input-117-b1076087f529>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   DIVERTED_AS = flights_df[flights_df.DIVERTED == 1][flights_df.AIRLINE == 'AS']['DIVERTED'].count()
# 413

# %%
Flight_AA = flights_df[flights_df.AIRLINE == 'AA']['AIRLINE'].count()
Flight_AA
# Out:
# 725984

# %%
CANCELLED_AA = flights_df[flights_df.CANCELLED == 1][flights_df.AIRLINE == 'AA']['CANCELLED'].count()
CANCELLED_AA
# Out:
# <ipython-input-129-d8d02a6241a4>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   CANCELLED_AA = flights_df[flights_df.CANCELLED == 1][flights_df.AIRLINE == 'AA']['CANCELLED'].count()
# 10919

# %%
DIVERTED_AA = flights_df[flights_df.DIVERTED == 1][flights_df.AIRLINE == 'AA']['DIVERTED'].count()
DIVERTED_AA
# Out:
# <ipython-input-130-4b0c72b3fec7>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   DIVERTED_AA = flights_df[flights_df.DIVERTED == 1][flights_df.AIRLINE == 'AA']['DIVERTED'].count()
# 2130

# %%
Flight_US = flights_df[flights_df.AIRLINE == 'US']['AIRLINE'].count()
Flight_US
# Out:
# 198715

# %%
CANCELLED_US = flights_df[flights_df.CANCELLED == 1][flights_df.AIRLINE == 'US']['CANCELLED'].count()
CANCELLED_US
# Out:
# <ipython-input-133-732e6b30a4a7>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   CANCELLED_US = flights_df[flights_df.CANCELLED == 1][flights_df.AIRLINE == 'US']['CANCELLED'].count()
# 4067

# %%
DIVERTED_US = flights_df[flights_df.DIVERTED == 1][flights_df.AIRLINE == 'US']['DIVERTED'].count()
DIVERTED_US
# Out:
# <ipython-input-134-a0d93131703d>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   DIVERTED_US = flights_df[flights_df.DIVERTED == 1][flights_df.AIRLINE == 'US']['DIVERTED'].count()
# 425

# %%
flights_df['AIRSPEED'] = flights_df['DISTANCE'] / flights_df['AIR_TIME']
flights_df
# Out:
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0        2015      1    1            4      AS             98      N407AS
# 1        2015      1    1            4      AA           2336      N3KUAA
# 2        2015      1    1            4      US            840      N171US
# 3        2015      1    1            4      AA            258      N3HYAA
# 4        2015      1    1            4      AS            135      N527AS
# ...       ...    ...  ...          ...     ...            ...         ...
# 5819074  2015     12   31            4      B6            688      N657JB
# 5819075  2015     12   31            4      B6            745      N828JB
# 5819076  2015     12   31            4      B6           1503      N913JB
# 5819077  2015     12   31            4      B6            333      N527JB
# 5819078  2015     12   31            4      B6            839      N534JB
#
#         ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  \
# ...

# %%
Full_AirTime_AS = flights_df[flights_df.AIRLINE == 'AS']['AIR_TIME'].sum()
Full_AirTime_AS
# Out:
# 27060752.0

# %%
Full_Distance_AS = flights_df[flights_df.AIRLINE == 'AS']['DISTANCE'].sum()
Full_Distance_AS
# Out:
# 206579765

# %%
Med_AirSpeed_AS = Full_Distance_AS / Full_AirTime_AS
Med_AirSpeed_AS
# Out:
# 7.63392550953499

# %%
Full_AirTime_AA = flights_df[flights_df.AIRLINE == 'AA']['AIR_TIME'].sum()
Full_AirTime_AA
# Out:
# 99672739.0

# %%
Full_Distance_AA = flights_df[flights_df.AIRLINE == 'AA']['DISTANCE'].sum()
Full_Distance_AA
# Out:
# 755995614

# %%
Med_AirSpeed_AA = Full_Distance_AA / Full_AirTime_AA
Med_AirSpeed_AA
# Out:
# 7.584778160857002

# %%
Full_AirTime_US = flights_df[flights_df.AIRLINE == 'US']['AIR_TIME'].sum()
Full_AirTime_US
# Out:
# 24428249.0

# %%
Full_Distance_US = flights_df[flights_df.AIRLINE == 'US']['DISTANCE'].sum()
Full_Distance_US
# Out:
# 181129490

# %%
Med_AirSpeed_US = Full_Distance_US / Full_AirTime_US
Med_AirSpeed_US
# Out:
# 7.414755351478528
