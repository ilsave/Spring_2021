# %% [markdown]
# # Лабораторная работа  №2. Предварительная обработка данных

# %% [markdown]
# Вариант 7

# %% [markdown]
# Выполнил: Брызгалов Андрей Геннадьевич
# Группа: 19-ИВТ-2

# %% [markdown]
# Цель лабораторной работы – получение навыков работы с библиотеками анализа данных, предварительной обработки данных, средствами визуализации.

# %% [markdown]
# ### Ход работы:

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
# %matplotlib inline


cam = pd.read_csv('camera_dataset.csv', delimiter = ',')
cam
# Out:
#                        Model  Release date  Max_resolution  Low_resolution  \
# 0           Agfa ePhoto 1280          1997          1024.0           640.0
# 1           Agfa ePhoto 1680          1998          1280.0           640.0
# 2           Agfa ePhoto CL18          2000           640.0             0.0
# 3           Agfa ePhoto CL30          1999          1152.0           640.0
# 4     Agfa ePhoto CL30 Clik!          1999          1152.0           640.0
# ...                      ...           ...             ...             ...
# 1033         Toshiba PDR-M65          2001          2048.0          1024.0
# 1034         Toshiba PDR-M70          2000          2048.0          1024.0
# 1035         Toshiba PDR-M71          2001          2048.0          1024.0
# 1036         Toshiba PDR-M81          2001          2400.0          1200.0
# 1037         Toshiba PDR-T10          2002          1600.0           800.0
#
# ...

# %%
cam.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1038 entries, 0 to 1037
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Model                    1038 non-null   object
#  1   Release date             1038 non-null   int64
#  2   Max_resolution           1038 non-null   float64
#  3   Low_resolution           1038 non-null   float64
#  4   Effective pixels         1038 non-null   float64
#  5   Zoom wide (W)            1038 non-null   float64
#  6   Zoom tele (T)            1038 non-null   float64
#  7   Normal_focus_range       1038 non-null   float64
#  8   Macro_focus_range        1037 non-null   float64
#  9   Storage included         1036 non-null   float64
#  10  Weight (inc. batteries)  1036 non-null   float64
#  11  Dimensions               1036 non-null   float64
#  12  Price                    1038 non-null   float64
# dtypes: float64(11), int64(1), object(1)
# ...

# %%
cam.head()
# Out:
#                     Model  Release date  Max_resolution  Low_resolution  \
# 0        Agfa ePhoto 1280          1997          1024.0           640.0
# 1        Agfa ePhoto 1680          1998          1280.0           640.0
# 2        Agfa ePhoto CL18          2000           640.0             0.0
# 3        Agfa ePhoto CL30          1999          1152.0           640.0
# 4  Agfa ePhoto CL30 Clik!          1999          1152.0           640.0
#
#    Effective pixels  Zoom wide (W)  Zoom tele (T)  Normal_focus_range  \
# 0               0.0           38.0          114.0                70.0
# 1               1.0           38.0          114.0                50.0
# 2               0.0           45.0           45.0                 0.0
# 3               0.0           35.0           35.0                 0.0
# 4               0.0           43.0           43.0                50.0
#
#    Macro_focus_range  Storage included  Weight (inc. batteries)  Dimensions  \
# ...

# %%
cam.tail()
# Out:
#                 Model  Release date  Max_resolution  Low_resolution  \
# 1033  Toshiba PDR-M65          2001          2048.0          1024.0
# 1034  Toshiba PDR-M70          2000          2048.0          1024.0
# 1035  Toshiba PDR-M71          2001          2048.0          1024.0
# 1036  Toshiba PDR-M81          2001          2400.0          1200.0
# 1037  Toshiba PDR-T10          2002          1600.0           800.0
#
#       Effective pixels  Zoom wide (W)  Zoom tele (T)  Normal_focus_range  \
# 1033               3.0           38.0          114.0                10.0
# 1034               3.0           35.0          105.0                80.0
# 1035               3.0           35.0           98.0                80.0
# 1036               3.0           35.0           98.0                80.0
# 1037               1.0           38.0           38.0                40.0
#
#       Macro_focus_range  Storage included  Weight (inc. batteries)  \
# ...

# %%
cam.describe()
# Out:
#        Release date  Max_resolution  Low_resolution  Effective pixels  \
# count   1038.000000     1038.000000     1038.000000       1038.000000
# mean    2003.590559     2474.672447     1773.936416          4.596339
# std        2.724755      759.513608      830.897955          2.844044
# min     1994.000000        0.000000        0.000000          0.000000
# 25%     2002.000000     2048.000000     1120.000000          3.000000
# 50%     2004.000000     2560.000000     2048.000000          4.000000
# 75%     2006.000000     3072.000000     2560.000000          7.000000
# max     2007.000000     5616.000000     4992.000000         21.000000
#
#        Zoom wide (W)  Zoom tele (T)  Normal_focus_range  Macro_focus_range  \
# count    1038.000000    1038.000000         1038.000000        1037.000000
# mean       32.963391     121.525048           44.145472           7.787850
# std        10.333149      93.455422           24.141959           8.100081
# ...

# %%
cam.drop_duplicates()
# Out:
#                        Model  Release date  Max_resolution  Low_resolution  \
# 0           Agfa ePhoto 1280          1997          1024.0           640.0
# 1           Agfa ePhoto 1680          1998          1280.0           640.0
# 2           Agfa ePhoto CL18          2000           640.0             0.0
# 3           Agfa ePhoto CL30          1999          1152.0           640.0
# 4     Agfa ePhoto CL30 Clik!          1999          1152.0           640.0
# ...                      ...           ...             ...             ...
# 1033         Toshiba PDR-M65          2001          2048.0          1024.0
# 1034         Toshiba PDR-M70          2000          2048.0          1024.0
# 1035         Toshiba PDR-M71          2001          2048.0          1024.0
# 1036         Toshiba PDR-M81          2001          2400.0          1200.0
# 1037         Toshiba PDR-T10          2002          1600.0           800.0
#
# ...

# %%
cam.shape
# Out:
# (1038, 13)

# %%
sns.heatmap(cam.corr(),annot=True)#функция для отображения коэффициента корреляции
# Out:
# <AxesSubplot:>

# %%
#корреляция Пирсона
a = cam['Price']
b = cam['Max_resolution']
stats.pearsonr(a, b)
# Out:
# (0.1832024591068465, 2.752833076825844e-09)

# %%
stats.spearmanr(cam['Price'], cam['Max_resolution'])
# Out:
# SpearmanrResult(correlation=0.10126852664923244, pvalue=0.0010863948570554284)

# %%
cam.Price.hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
cam.Max_resolution.hist(bins = 20)
# Out:
# <AxesSubplot:>

# %%
def lastname(name):
    return name.split(' ')[0].strip()
company = cam['Model'].apply(lastname)
cam['Company'] = company
cam.head()
# Out:
#                     Model  Release date  Max_resolution  Low_resolution  \
# 0        Agfa ePhoto 1280          1997          1024.0           640.0
# 1        Agfa ePhoto 1680          1998          1280.0           640.0
# 2        Agfa ePhoto CL18          2000           640.0             0.0
# 3        Agfa ePhoto CL30          1999          1152.0           640.0
# 4  Agfa ePhoto CL30 Clik!          1999          1152.0           640.0
#
#    Effective pixels  Zoom wide (W)  Zoom tele (T)  Normal_focus_range  \
# 0               0.0           38.0          114.0                70.0
# 1               1.0           38.0          114.0                50.0
# 2               0.0           45.0           45.0                 0.0
# 3               0.0           35.0           35.0                 0.0
# 4               0.0           43.0           43.0                50.0
#
#    Macro_focus_range  Storage included  Weight (inc. batteries)  Dimensions  \
# ...

# %%
cam.Company.value_counts().head(1)
# Out:
# Olympus    122
# Name: Company, dtype: int64

# %%
cam['N*M'] = cam['Normal_focus_range'] * cam['Macro_focus_range']
cam
# Out:
#                        Model  Release date  Max_resolution  Low_resolution  \
# 0           Agfa ePhoto 1280          1997          1024.0           640.0
# 1           Agfa ePhoto 1680          1998          1280.0           640.0
# 2           Agfa ePhoto CL18          2000           640.0             0.0
# 3           Agfa ePhoto CL30          1999          1152.0           640.0
# 4     Agfa ePhoto CL30 Clik!          1999          1152.0           640.0
# ...                      ...           ...             ...             ...
# 1033         Toshiba PDR-M65          2001          2048.0          1024.0
# 1034         Toshiba PDR-M70          2000          2048.0          1024.0
# 1035         Toshiba PDR-M71          2001          2048.0          1024.0
# 1036         Toshiba PDR-M81          2001          2400.0          1200.0
# 1037         Toshiba PDR-T10          2002          1600.0           800.0
#
# ...

# %%
price = pd.DataFrame(cam.groupby(['Release date'])['Company'].sum())
price =pd.DataFrame(price['Company'].str.count('[A-Z]'))
price.sort_values(by = ['Release date'], ascending = False).head(1)
# Out:
#               Company
# Release date
# 2007              170

# %%
price3['average'] = price3['Price']/price3['count']
price3 = price3.reset_index()
price3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-8c874bdd24b4> in <module>
# ----> 1 price3['average'] = price3['Price']/price3['count']
#       2 price3 = price3.reset_index()
#       3 price3
#
# NameError: name 'price3' is not defined

# %%
price3 = price3.rename(columns={'Release date': 'Release_date'})
plt.plot(price3["Release_date"], price3["average"])

# %%
price=pd.DataFrame(cameras.groupby(['Price']))
price.head(1)

# %%
price.tail(1)
